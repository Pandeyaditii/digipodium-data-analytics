# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
marks = pd.read_excel('marksheet_faked.xlsx')
marks
# Out:
#     S.no   First name   Last name  DM  SE  GFX  DBMS  ECO
# 0      1     Sandhya        Singh  60  87   34    55   79
# 1      2       Pinki        Yadav  49  73   53    51   96
# 2      3      Ankita        Verma  77  77   96    93   79
# 3      4   Dipanjali        Singh  67  36   37    89   39
# 4      5      Khushi      Awasthi  34  90   59    33   47
# 5      6     Shalini          Pal  33  64   97    59   67
# 6      7      Saloni         Gond  60  64  100    97   37
# 7      8     Anushka   Srivastava  62  44   94    89   52
# 8      9       Aditi       Pandey  30  91   63   100   84
# 9     10       Umama        Anjum  84  38   37    92   86
# 10    11      Muskan        Singh  44  58   74    81   57
# 11    12       Kajal       Pandey  83  54   40    75   30
# 12    13     Anshika        Yadav  35  55   57    73   79
# 13    14     Deepika         Soni  69  87   99    82   75
# 14    15     Srishti      Kashyap  77  75   93    62   49
# 15    16  Pratishtha        Singh  41  35   82    47   62
# 16    17     Kritika       Kumari  50  95   91    94   85
# 17    18      Shilpa        Singh  42  74   53    92   84
# 18    19       Komal       Sharma  55  73   81    93   79
# 19    20      Deepti        Singh  53  86   90    93   81

# %%
marks.set_index('First name', inplace=True)
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  60  87   34    55   79
# Pinki           2       Yadav  49  73   53    51   96
# Ankita          3       Verma  77  77   96    93   79
# Dipanjali       4       Singh  67  36   37    89   39
# Khushi          5     Awasthi  34  90   59    33   47
# Shalini         6         Pal  33  64   97    59   67
# Saloni          7        Gond  60  64  100    97   37
# Anushka         8  Srivastava  62  44   94    89   52
# Aditi           9      Pandey  30  91   63   100   84
# Umama          10       Anjum  84  38   37    92   86
# Muskan         11       Singh  44  58   74    81   57
# Kajal          12      Pandey  83  54   40    75   30
# Anshika        13       Yadav  35  55   57    73   79
# Deepika        14        Soni  69  87   99    82   75
# Srishti        15     Kashyap  77  75   93    62   49
# Pratishtha     16       Singh  41  35   82    47   62
# Kritika        17      Kumari  50  95   91    94   85
# Shilpa         18       Singh  42  74   53    92   84
# Komal          19      Sharma  55  73   81    93   79
# Deepti         20       Singh  53  86   90    93   81

# %%
marks[['ECO', 'GFX','DM','SE','DBMS']].plot(kind='bar', figsize=(10,5), title='ECO Marks')
# Out:
# <Axes: title={'center': 'ECO Marks'}, xlabel='First name'>

# %%
marks.index
# Out:
# Index(['Sandhya ', 'Pinki ', 'Ankita ', 'Dipanjali ', 'Khushi ', 'Shalini ',
#        'Saloni ', 'Anushka ', 'Aditi ', 'Umama ', 'Muskan ', 'Kajal ',
#        'Anshika ', 'Deepika ', 'Srishti ', 'Pratishtha ', 'Kritika ',
#        'Shilpa ', 'Komal ', 'Deepti '],
#       dtype='object', name='First name')

# %%
marks['GFX'] # selecting a colum (series)
# Out:
# First name
# Sandhya         34
# Pinki           53
# Ankita          96
# Dipanjali       37
# Khushi          59
# Shalini         97
# Saloni         100
# Anushka         94
# Aditi           63
# Umama           37
# Muskan          74
# Kajal           40
# Anshika         57
# Deepika         99
# Srishti         93
# Pratishtha      82
# Kritika         91
# Shilpa          53
# Komal           81
# Deepti          90
# Name: GFX, dtype: int64

# %%
marks.columns # only column
# Out:
# Index(['S.no', 'Last name', 'DM', 'SE', 'GFX', 'DBMS', 'ECO'], dtype='object')

# %%
marks['ECO'] **2
# Out:
# First name
# Sandhya        6241
# Pinki          9216
# Ankita         6241
# Dipanjali      1521
# Khushi         2209
# Shalini        4489
# Saloni         1369
# Anushka        2704
# Aditi          7056
# Umama          7396
# Muskan         3249
# Kajal           900
# Anshika        6241
# Deepika        5625
# Srishti        2401
# Pratishtha     3844
# Kritika        7225
# Shilpa         7056
# Komal          6241
# Deepti         6561
# Name: ECO, dtype: int64

# %%
marks['DM'] += 2 #grace marks

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO
# First name
# Sandhya         1       Singh  62  87   34    55   79
# Pinki           2       Yadav  51  73   53    51   96
# Ankita          3       Verma  79  77   96    93   79
# Dipanjali       4       Singh  69  36   37    89   39
# Khushi          5     Awasthi  36  90   59    33   47
# Shalini         6         Pal  35  64   97    59   67
# Saloni          7        Gond  62  64  100    97   37
# Anushka         8  Srivastava  64  44   94    89   52
# Aditi           9      Pandey  32  91   63   100   84
# Umama          10       Anjum  86  38   37    92   86
# Muskan         11       Singh  46  58   74    81   57
# Kajal          12      Pandey  85  54   40    75   30
# Anshika        13       Yadav  37  55   57    73   79
# Deepika        14        Soni  71  87   99    82   75
# Srishti        15     Kashyap  79  75   93    62   49
# Pratishtha     16       Singh  43  35   82    47   62
# Kritika        17      Kumari  52  95   91    94   85
# Shilpa         18       Singh  44  74   53    92   84
# Komal          19      Sharma  57  73   81    93   79
# Deepti         20       Singh  55  86   90    93   81

# %%
marks[['DBMS', 'DM']] # selecting muntiple colunms
# Out:
#              DBMS  DM
# First name
# Sandhya        55  62
# Pinki          51  51
# Ankita         93  79
# Dipanjali      89  69
# Khushi         33  36
# Shalini        59  35
# Saloni         97  62
# Anushka        89  64
# Aditi         100  32
# Umama          92  86
# Muskan         81  46
# Kajal          75  85
# Anshika        73  37
# Deepika        82  71
# Srishti        62  79
# Pratishtha     47  43
# Kritika        94  52
# Shilpa         92  44
# Komal          93  57
# Deepti         93  55

# %%
marks['total']= marks['DBMS'] + marks['DM'] + marks['ECO'] + marks['GFX']+ marks['SE']

# %%
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total
# First name
# Sandhya         1       Singh  62  87   34    55   79    317
# Pinki           2       Yadav  51  73   53    51   96    324
# Ankita          3       Verma  79  77   96    93   79    424
# Dipanjali       4       Singh  69  36   37    89   39    270
# Khushi          5     Awasthi  36  90   59    33   47    265
# Shalini         6         Pal  35  64   97    59   67    322
# Saloni          7        Gond  62  64  100    97   37    360
# Anushka         8  Srivastava  64  44   94    89   52    343
# Aditi           9      Pandey  32  91   63   100   84    370
# Umama          10       Anjum  86  38   37    92   86    339
# Muskan         11       Singh  46  58   74    81   57    316
# Kajal          12      Pandey  85  54   40    75   30    284
# Anshika        13       Yadav  37  55   57    73   79    301
# Deepika        14        Soni  71  87   99    82   75    414
# Srishti        15     Kashyap  79  75   93    62   49    358
# Pratishtha     16       Singh  43  35   82    47   62    269
# Kritika        17      Kumari  52  95   91    94   85    417
# Shilpa         18       Singh  44  74   53    92   84    347
# Komal          19      Sharma  57  73   81    93   79    383
# Deepti         20       Singh  55  86   90    93   81    405

# %%
marks['total'].plot(kind='pie', figsize=(10,5), title='Result')
# Out:
# <Axes: title={'center': 'Result'}, ylabel='total'>

# %%
# sorting
marks.sort_values(by='total', ascending=False, inplace=True)
marks
# Out:
#              S.no   Last name  DM  SE  GFX  DBMS  ECO  total
# First name
# Ankita          3       Verma  79  77   96    93   79    424
# Kritika        17      Kumari  52  95   91    94   85    417
# Deepika        14        Soni  71  87   99    82   75    414
# Deepti         20       Singh  55  86   90    93   81    405
# Komal          19      Sharma  57  73   81    93   79    383
# Aditi           9      Pandey  32  91   63   100   84    370
# Saloni          7        Gond  62  64  100    97   37    360
# Srishti        15     Kashyap  79  75   93    62   49    358
# Shilpa         18       Singh  44  74   53    92   84    347
# Anushka         8  Srivastava  64  44   94    89   52    343
# Umama          10       Anjum  86  38   37    92   86    339
# Pinki           2       Yadav  51  73   53    51   96    324
# Shalini         6         Pal  35  64   97    59   67    322
# Sandhya         1       Singh  62  87   34    55   79    317
# Muskan         11       Singh  46  58   74    81   57    316
# Anshika        13       Yadav  37  55   57    73   79    301
# Kajal          12      Pandey  85  54   40    75   30    284
# Dipanjali       4       Singh  69  36   37    89   39    270
# Pratishtha     16       Singh  43  35   82    47   62    269
# Khushi          5     Awasthi  36  90   59    33   47    265

# %%
marks['percentage']= marks['total']/5

# %%
marks.sort_values(by=['total', 'percentage'], ascending=False, inplace=True)

# %%
fig, ax= plt.subplots(figsize=(15,5), ncols=2)
marks['total'].plot(kind='line',ax=ax[0])
cols= ['DBMS','DM','ECO','GFX','SE']
marks[cols].plot(kind='hist', ax=ax[1])
plt.show()

# %%
marks.groupby('Last name')['total'].mean()
# Out:
# Last name
# Anjum         339.000000
# Awasthi       265.000000
# Gond          360.000000
# Kashyap       358.000000
# Kumari        417.000000
# Pal           322.000000
# Pandey        327.000000
# Sharma        383.000000
# Singh         320.666667
# Soni          414.000000
# Srivastava    343.000000
# Verma         424.000000
# Yadav         312.500000
# Name: total, dtype: float64
